# %% [markdown]
# # LOAD DATABASE (FROM LOCAL .CSV)

# %%
import pandas as pd
import numpy as np
from google.colab import files
import io

key = '/content/Base_Nao_Normalizada_EnrichedGA_descValuables.csv'
sample_df = pd.read_csv(key)
print(sample_df.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from google.colab import files
#       4 import io
#       6 key = '/content/Base_Nao_Normalizada_EnrichedGA_descValuables.csv'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
v_ToRemove = ["csm1", "quantidadeFAD", "Emboss23", "Emboss29", "Emboss2", "quantidadeFerro", "'Desc. Local. \% Hidrofobico'", "Emboss26"]
sample_df = sample_df.drop(v_ToRemove, axis=1)
key = key + ' (+ TOP15Ranking)'

sample_df.head()
sample_df.shape

# %% [markdown]
# # Definições do Projeto

# %%
#variáveis globais/paramétricas para o projeto
className = 'classe'
numClasses = 6

#Normalização Min-Max
from sklearn.preprocessing import MinMaxScaler
#=============================================================
from datetime import datetime
from pytz import timezone
def timenow():
  data_e_hora_atuais = datetime.now()
  fuso_horario = timezone('America/Sao_Paulo')
  data_e_hora_sao_paulo = data_e_hora_atuais.astimezone(fuso_horario)
  data_e_hora_sao_paulo_em_texto = data_e_hora_sao_paulo.strftime('%d/%m/%Y %H:%M')
  print(data_e_hora_sao_paulo_em_texto)

# %% [markdown]
# # GRIDSEARCH

# %%
#range-space
import numpy as np
C_range = np.logspace(-15, 15, 10, base=2)
gamma_range = np.logspace(-15, 15, 10, base=2)

for C in C_range:
  print(C)

# %% [markdown]
# # SVM MODEL
#
# ---

# %% [markdown]
# ## SVM_OVERSAMPLING

# %%
#SVM COM BALANCEAMENTO

import pandas as pd 
from sklearn.model_selection import KFold, StratifiedKFold, StratifiedShuffleSplit, cross_val_score, cross_val_predict, GridSearchCV
import numpy as np
from sklearn import preprocessing
from sklearn import decomposition
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE

seed = 42
best = 0
num_folders = 10;

timenow()
for param in range(1,11):
  df = sample_df
  X = df.drop([className], axis=1).values
  Y = df[className].values

  feature_names = list(df.drop([className], axis=1).columns.values)
  target_name = [className]

  processed_X = pd.DataFrame(X, columns=feature_names) #DataFrame sem a classe (criação de DataFrame dos dados com os nomes das colunas)
  folder = StratifiedKFold(n_splits=num_folders, random_state=seed, shuffle=True) #objeto folder para separar CV-10

  kernel = 'rbf'

  cost =  0#input
  gamma = 0#input

  f1_cvscores = []
  f1_mean = []
  f1_std = []

  recall_cvscores = []
  recall_mean = []
  recall_std = []

  precision_cvscores = []
  precision_mean = []
  precision_std = []

  print(key)
  print(cost)
  print(gamma)
  fig_count = 1;
  
  for index, (train, test) in enumerate(folder.split(X, Y)):
      scaler = MinMaxScaler(feature_range=(0,1))
      s_train = scaler.fit_transform(X[train])
      (X_train, Y_train) = (s_train, Y[train])

      #(X_train, Y_train) = (X[train], Y[train])

      print("Training on fold " + str(index+1) + "/10...")
      #Balanceamento do conjunto de treinamento (em um i-fold especificamente)    
      #----------smote normal----------------------------
      sm = SMOTE(sampling_strategy='not majority', random_state=seed, n_jobs=-1, k_neighbors=param)
      #import pdb; pdb.set_trace()
      X_train, Y_train = sm.fit_resample(X_train, Y_train)
      #import pdb; pdb.set_trace()  
      #-------------svm-smote------------------------------
      #from imblearn.over_sampling import SVMSMOTE
      #model = SVC(C=cost, gamma=gamma, kernel = kernel, random_state=seed)
      #svmST = SVMSMOTE(sampling_strategy='not majority', svm_estimator=model, random_state=seed, n_jobs=-1, k_neighbors=param)
      #(X_train, Y_train) = svmST.fit_resample(s_train, Y[train])
      #-------------borderline-smote------------------------------
      #from imblearn.over_sampling import BorderlineSMOTE
      #borderSmote = BorderlineSMOTE(sampling_strategy='not majority', random_state=seed, n_jobs=2)
      #(X_train, Y_train) = borderSmote.fit_resample(X[train], Y[train])
      #//////////////////TOMEK////////////////////////////
      #sampler_classes = list(["'OXIDORREDUTASES '", "TRANSFERASES", "HIDROLASES"])
      #from imblearn.under_sampling import TomekLinks
      #tl = TomekLinks(sampling_strategy=sampler_classes)
      #(X_train,Y_train) = tl.fit_sample(X_train, Y_train)
      #//////////////////////////////////////////////////
      
      model = SVC(C=cost, gamma=gamma, kernel = kernel, random_state=seed)

      #Treinamento
      model.fit(X_train, Y_train)

      #Teste
      s_test = scaler.transform(X[test])
      y_pred = model.predict(s_test)

      #Avaliação
        
      f1_micro = f1_score(Y[test], y_pred, average='micro')  
      f1_macro = f1_score(Y[test], y_pred, average='macro')    
      
      f1_cvscores.append(f1_score(Y[test], y_pred, average=None))
      recall_cvscores.append(recall_score(Y[test], y_pred, average=None))
      precision_cvscores.append(precision_score(Y[test], y_pred, average=None))

      cm = confusion_matrix(Y[test], y_pred, labels=model.classes_)
      print(cm)
      disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
      import matplotlib.pyplot as plt
      disp.plot()
      tick_marks = np.arange(len(model.classes_))
      plt.xticks(tick_marks, ['EC1','EC3','EC5','EC4','EC6','EC2'], rotation=0)
      plt.yticks(tick_marks, ["Oxidoreductases (EC1)",'Hydrolases (EC3)','Isomerases (EC5)','Lyases (EC4)','Ligases (EC6)','Transferases (EC2)'],  rotation=0)
      plt.savefig('/content/cm_folder'+ str(fig_count)+'.png', format='png', dpi=300, bbox_inches = 'tight')
      fig_count = fig_count+1
     
      plt.show()  
      print(classification_report(Y[test], y_pred, digits=8))
 
#To-do: refactoring code below to void duplicating code.
  f1_values = list(zip(*f1_cvscores))
  recall_values = list(zip(*recall_cvscores))
  precision_values = list(zip(*precision_cvscores))
  
  
    #for i, val in enumerate(f1_values):
  for i in range(0, numClasses):
      f1_mean.append(np.mean(f1_values[i]))
      f1_std.append(np.std(f1_values[i]))
      recall_mean.append(np.mean(recall_values[i]))
      recall_std.append(np.std(recall_values[i]))
      precision_mean.append(np.mean(precision_values[i]))
      precision_std.append(np.std(precision_values[i]))
 
  #import pdb; pdb.set_trace()
  print("-----\nMédia por Classe (F-measure):")
  print('(<valores da classe em questão>)\n')
  for x in range(0, numClasses):
      print("%s: %.4f (+/- %.4f)" % (model.classes_[x], f1_mean[x], f1_std[x]))
      print(f1_values[x],'\n')
  print("%s: %.4f (+/- %.4f)" % ('Average', np.mean(f1_cvscores), np.std(f1_cvscores)))

  print("-----\nMédia por Classe (Recall): \n")
  print('(<valores da classe em questão>)\n')
  for x in range(0, numClasses):
      print("%s: %.4f (+/- %.4f)" % (model.classes_[x], recall_mean[x], recall_std[x]))
      print(recall_values[x],'\n')
  print("%s: %.4f (+/- %.4f)" % ('Average', np.mean(recall_cvscores), np.std(recall_cvscores)))

  print("-----\nMédia por Classe (Precision): \n")
  print('(<valores da classe em questão>)\n')
  for x in range(0, numClasses):
      print("%s: %.4f (+/- %.4f)" % (model.classes_[x], precision_mean[x], precision_std[x]))
      print(precision_values[x],'\n')
  print("%s: %.4f (+/- %.4f)" % ('Average', np.mean(precision_cvscores), np.std(precision_cvscores)))
  

  print('==========================================================')  
  print('param_K = ', param)
  if np.mean(f1_cvscores)>best:
    best = np.mean(f1_cvscores)
  #import pdb;pdb.set_trace()
print(best)
timenow()

 #------------------------------------------------------
 #OTHER IMPLEMENTATIONS
 #-------------------------------------------------------
 #//////////////////SMOTE-TOMEK////////////////////////////
  #from imblearn.combine import SMOTETomek
  # stl = SMOTETomek(sampling_strategy='not majority', random_state=seed)
  #(X_train,Y_train) = stl.fit_sample(X_train, Y_train)

 #///////////////////////ADASYN////////////////////////////
   #from imblearn.over_sampling import ADASYN
   #ada = ADASYN(sampling_strategy='not majority', random_state=seed, n_jobs=-1)
   #(X_train, Y_train) = ada.fit_resample(X[train], Y[train])
# Out:
# 03/02/2023 13:56
# /content/Base_Nao_Normalizada_EnrichedGA_descValuables.csv
# 32.0
# 3.174802
# Training on fold 1/10...
# [[276  10   5   6   1   2]
#  [  6 550   3  15   3  12]
#  [  4  11  70   1   0   4]
#  [  4  17   2 108   1   6]
#  [  2  20   1   6  75   1]
#  [  0  30   2   6   2 466]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.94520548 0.92000000 0.93243243       300
#         HIDROLASES  0.86206897 0.93378608 0.89649552       589
#         ISOMERASES  0.84337349 0.77777778 0.80924855        90
#             LIASES  0.76056338 0.78260870 0.77142857       138
#            LIGASES  0.91463415 0.71428571 0.80213904       105
#       TRANSFERASES  0.94908350 0.92094862 0.93480441       506
#
#           accuracy                      0.89409722      1728
#          macro avg  0.87915483 0.84156781 0.85775809      1728
#       weighted avg  0.89609633 0.89409722 0.89368677      1728
#
# Training on fold 2/10...
# [[280  14   4   1   0   1]
#  [  3 549   1  15   6  15]
#  [ 10   9  63   2   2   4]
#  [  2  18   2 109   2   5]
#  [  1  18   1   2  79   4]
#  [  2  23   2   7   3 469]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.93959732 0.93333333 0.93645485       300
#         HIDROLASES  0.87004754 0.93208829 0.90000000       589
#         ISOMERASES  0.86301370 0.70000000 0.77300613        90
#             LIASES  0.80147059 0.78985507 0.79562044       138
#            LIGASES  0.85869565 0.75238095 0.80203046       105
#       TRANSFERASES  0.94176707 0.92687747 0.93426295       506
#
#           accuracy                      0.89641204      1728
#          macro avg  0.87909864 0.83908919 0.85689580      1728
#       weighted avg  0.89659060 0.89641204 0.89545884      1728
#
# Training on fold 3/10...
# [[281  13   2   2   1   1]
#  [  1 549   2  12   9  16]
#  [  7   9  70   1   0   3]
#  [  4  14   0 112   2   6]
#  [  0  12   0   1  86   6]
#  [  3  29   0   5   1 468]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.94932432 0.93666667 0.94295302       300
#         HIDROLASES  0.87699681 0.93208829 0.90370370       589
#         ISOMERASES  0.94594595 0.77777778 0.85365854        90
#             LIASES  0.84210526 0.81159420 0.82656827       138
#            LIGASES  0.86868687 0.81904762 0.84313725       105
#       TRANSFERASES  0.93600000 0.92490119 0.93041750       506
#
#           accuracy                      0.90625000      1728
#          macro avg  0.90317653 0.86701262 0.88340638      1728
#       weighted avg  0.90713090 0.90625000 0.90589337      1728
#
# Training on fold 4/10...
# [[272  14   4   6   1   3]
#  [  3 549   4  11   5  17]
#  [ 13   6  66   3   0   2]
#  [  8  15   2 100   4   9]
#  [  0  15   0   4  82   4]
#  [  1  26   4   6   3 466]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.91582492 0.90666667 0.91122278       300
#         HIDROLASES  0.87840000 0.93208829 0.90444811       589
#         ISOMERASES  0.82500000 0.73333333 0.77647059        90
#             LIASES  0.76923077 0.72463768 0.74626866       138
#            LIGASES  0.86315789 0.78095238 0.82000000       105
#       TRANSFERASES  0.93013972 0.92094862 0.92552135       506
#
#           accuracy                      0.88831019      1728
#          macro avg  0.86362555 0.83310449 0.84732191      1728
#       weighted avg  0.88762222 0.88831019 0.88736574      1728
#
# Training on fold 5/10...
# [[286   4   3   2   1   4]
#  [  9 545   2  11   7  15]
#  [  8  13  64   0   1   4]
#  [  5  13   0 108   6   6]
#  [  2  17   1   3  76   6]
#  [  9  32   0   5   2 458]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.89655172 0.95333333 0.92407108       300
#         HIDROLASES  0.87339744 0.92529711 0.89859852       589
#         ISOMERASES  0.91428571 0.71111111 0.80000000        90
#             LIASES  0.83720930 0.78260870 0.80898876       138
#            LIGASES  0.81720430 0.72380952 0.76767677       105
#       TRANSFERASES  0.92900609 0.90513834 0.91691692       506
#
#           accuracy                      0.88946759      1728
#          macro avg  0.87794243 0.83354969 0.85270867      1728
#       weighted avg  0.88952589 0.88946759 0.88813792      1728
#
# Training on fold 6/10...
# [[277   9   5   3   2   4]
#  [ 10 531   3  15  11  19]
#  [  8   6  68   4   2   2]
#  [  5  18   0 107   0   8]
#  [  3  25   0   1  75   1]
#  [  3  27   2   6   6 461]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.90522876 0.92333333 0.91419142       300
#         HIDROLASES  0.86201299 0.90152801 0.88132780       589
#         ISOMERASES  0.87179487 0.75555556 0.80952381        90
#             LIASES  0.78676471 0.77536232 0.78102190       138
#            LIGASES  0.78125000 0.71428571 0.74626866       105
#       TRANSFERASES  0.93131313 0.91287129 0.92200000       505
#
#           accuracy                      0.87955993      1727
#          macro avg  0.85639408 0.83048937 0.84238893      1727
#       weighted avg  0.87937101 0.87955993 0.87896113      1727
#
# Training on fold 7/10...
# [[276  12   4   4   1   3]
#  [  5 546   1  17   6  14]
#  [  3   9  72   3   1   1]
#  [  4  22   0 110   0   3]
#  [  0  16   1   4  79   5]
#  [  2  22   2   5   2 472]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.95172414 0.92000000 0.93559322       300
#         HIDROLASES  0.87081340 0.92699491 0.89802632       589
#         ISOMERASES  0.90000000 0.80898876 0.85207101        89
#             LIASES  0.76923077 0.79136691 0.78014184       139
#            LIGASES  0.88764045 0.75238095 0.81443299       105
#       TRANSFERASES  0.94779116 0.93465347 0.94117647       505
#
#           accuracy                      0.90040533      1727
#          macro avg  0.88786665 0.85573083 0.87024031      1727
#       weighted avg  0.90172912 0.90040533 0.90023108      1727
#
# Training on fold 8/10...
# [[275  14   5   2   1   4]
#  [  6 537   6  14  12  14]
#  [  3   9  69   3   1   4]
#  [  3  13   4 107   4   7]
#  [  2  23   0   0  74   6]
#  [  3  24   2  12   5 459]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.94178082 0.91362126 0.92748735       301
#         HIDROLASES  0.86612903 0.91171477 0.88833747       589
#         ISOMERASES  0.80232558 0.77528090 0.78857143        89
#             LIASES  0.77536232 0.77536232 0.77536232       138
#            LIGASES  0.76288660 0.70476190 0.73267327       105
#       TRANSFERASES  0.92914980 0.90891089 0.91891892       505
#
#           accuracy                      0.88071801      1727
#          macro avg  0.84627236 0.83160867 0.83855846      1727
#       weighted avg  0.88092458 0.88071801 0.88047022      1727
#
# Training on fold 9/10...
# [[283  11   2   3   1   1]
#  [  6 541   6  10   7  18]
#  [  6  14  66   3   0   1]
#  [  3  19   0 109   0   7]
#  [  2  21   0   1  78   3]
#  [  3  15   2   1   1 483]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.93399340 0.94019934 0.93708609       301
#         HIDROLASES  0.87117552 0.92006803 0.89495451       588
#         ISOMERASES  0.86842105 0.73333333 0.79518072        90
#             LIASES  0.85826772 0.78985507 0.82264151       138
#            LIGASES  0.89655172 0.74285714 0.81250000       105
#       TRANSFERASES  0.94152047 0.95643564 0.94891945       505
#
#           accuracy                      0.90330052      1727
#          macro avg  0.89498831 0.84712476 0.86854705      1727
#       weighted avg  0.90306186 0.90330052 0.90208673      1727
#
# Training on fold 10/10...
# [[284   7   0   4   0   6]
#  [ 11 541   5   8  15   8]
#  [  6   8  67   2   1   6]
#  [  5  17   3 110   0   3]
#  [  0  14   0   4  81   6]
#  [  3  25   3   6   3 465]]
#                     precision    recall  f1-score   support
#
# 'OXIDORREDUTASES '  0.91909385 0.94352159 0.93114754       301
#         HIDROLASES  0.88398693 0.92006803 0.90166667       588
#         ISOMERASES  0.85897436 0.74444444 0.79761905        90
#             LIASES  0.82089552 0.79710145 0.80882353       138
#            LIGASES  0.81000000 0.77142857 0.79024390       105
#       TRANSFERASES  0.94129555 0.92079208 0.93093093       505
#
#           accuracy                      0.89635206      1727
#          macro avg  0.87237437 0.84955936 0.86007194      1727
#       weighted avg  0.89602032 0.89635206 0.89574667      1727
#
# -----
# Média por Classe (F-measure):
# (<valores da classe em questão>)
#
# 'OXIDORREDUTASES ': 0.9293 (+/- 0.0097)
# (0.9324324324324323, 0.9364548494983278, 0.9429530201342282, 0.9112227805695142, 0.9240710823909531, 0.9141914191419143, 0.9355932203389831, 0.927487352445194, 0.9370860927152318, 0.9311475409836065)
#
# HIDROLASES: 0.8968 (+/- 0.0068)
# (0.8964955175224125, 0.9, 0.9037037037037037, 0.9044481054365733, 0.898598516075845, 0.8813278008298755, 0.8980263157894736, 0.8883374689826302, 0.8949545078577337, 0.9016666666666666)
#
# ISOMERASES: 0.8055 (+/- 0.0263)
# (0.8092485549132947, 0.7730061349693251, 0.8536585365853658, 0.776470588235294, 0.8, 0.8095238095238095, 0.8520710059171598, 0.7885714285714286, 0.7951807228915663, 0.7976190476190476)
#
# LIASES: 0.7917 (+/- 0.0240)
# (0.7714285714285714, 0.7956204379562044, 0.8265682656826568, 0.7462686567164178, 0.8089887640449438, 0.7810218978102189, 0.7801418439716313, 0.7753623188405797, 0.8226415094339623, 0.8088235294117647)
#
# LIGASES: 0.7931 (+/- 0.0327)
# (0.8021390374331552, 0.802030456852792, 0.8431372549019608, 0.8200000000000001, 0.7676767676767677, 0.7462686567164178, 0.8144329896907216, 0.7326732673267325, 0.8125, 0.7902439024390244)
#
# TRANSFERASES: 0.9304 (+/- 0.0095)
# (0.9348044132397192, 0.9342629482071714, 0.9304174950298212, 0.9255213505461767, 0.916916916916917, 0.922, 0.9411764705882353, 0.9189189189189189, 0.9489194499017681, 0.9309309309309309)
#
# Average: 0.8578 (+/- 0.0655)
# -----
# Média por Classe (Recall):
#
# (<valores da classe em questão>)
#
# 'OXIDORREDUTASES ': 0.9291 (+/- 0.0139)
# (0.92, 0.9333333333333333, 0.9366666666666666, 0.9066666666666666, 0.9533333333333334, 0.9233333333333333, 0.92, 0.9136212624584718, 0.9401993355481728, 0.9435215946843853)
#
# HIDROLASES: 0.9236 (+/- 0.0099)
# (0.933786078098472, 0.9320882852292021, 0.9320882852292021, 0.9320882852292021, 0.9252971137521222, 0.9015280135823429, 0.9269949066213922, 0.9117147707979627, 0.9200680272108843, 0.9200680272108843)
#
# ISOMERASES: 0.7518 (+/- 0.0320)
# (0.7777777777777778, 0.7, 0.7777777777777778, 0.7333333333333333, 0.7111111111111111, 0.7555555555555555, 0.8089887640449438, 0.7752808988764045, 0.7333333333333333, 0.7444444444444445)
#
# LIASES: 0.7820 (+/- 0.0217)
# (0.782608695652174, 0.7898550724637681, 0.8115942028985508, 0.7246376811594203, 0.782608695652174, 0.7753623188405797, 0.7913669064748201, 0.7753623188405797, 0.7898550724637681, 0.7971014492753623)
#
# LIGASES: 0.7476 (+/- 0.0339)
# (0.7142857142857143, 0.7523809523809524, 0.819047619047619, 0.780952380952381, 0.7238095238095238, 0.7142857142857143, 0.7523809523809524, 0.7047619047619048, 0.7428571428571429, 0.7714285714285715)
#
# TRANSFERASES: 0.9232 (+/- 0.0138)
# (0.9209486166007905, 0.9268774703557312, 0.924901185770751, 0.9209486166007905, 0.9051383399209486, 0.9128712871287129, 0.9346534653465347, 0.9089108910891089, 0.9564356435643564, 0.9207920792079208)
#
# Average: 0.8429 (+/- 0.0862)
# -----
# Média por Classe (Precision):
#
# (<valores da classe em questão>)
#
# 'OXIDORREDUTASES ': 0.9298 (+/- 0.0184)
# (0.9452054794520548, 0.9395973154362416, 0.9493243243243243, 0.9158249158249159, 0.896551724137931, 0.9052287581699346, 0.9517241379310345, 0.9417808219178082, 0.933993399339934, 0.919093851132686)
#
# HIDROLASES: 0.8715 (+/- 0.0067)
# (0.8620689655172413, 0.8700475435816165, 0.8769968051118211, 0.8784, 0.8733974358974359, 0.862012987012987, 0.8708133971291866, 0.8661290322580645, 0.8711755233494364, 0.8839869281045751)
#
# ISOMERASES: 0.8693 (+/- 0.0401)
# (0.8433734939759037, 0.863013698630137, 0.9459459459459459, 0.825, 0.9142857142857143, 0.8717948717948718, 0.9, 0.8023255813953488, 0.868421052631579, 0.8589743589743589)
#
# LIASES: 0.8021 (+/- 0.0334)
# (0.7605633802816901, 0.8014705882352942, 0.8421052631578947, 0.7692307692307693, 0.8372093023255814, 0.7867647058823529, 0.7692307692307693, 0.7753623188405797, 0.8582677165354331, 0.8208955223880597)
#
# LIGASES: 0.8461 (+/- 0.0482)
# (0.9146341463414634, 0.8586956521739131, 0.8686868686868687, 0.8631578947368421, 0.8172043010752689, 0.78125, 0.8876404494382022, 0.7628865979381443, 0.896551724137931, 0.81)
#
# TRANSFERASES: 0.9377 (+/- 0.0072)
# (0.9490835030549898, 0.9417670682730924, 0.936, 0.9301397205588823, 0.9290060851926978, 0.9313131313131313, 0.9477911646586346, 0.9291497975708503, 0.9415204678362573, 0.9412955465587044)
#
# Average: 0.8761 (+/- 0.0557)
# ==========================================================
# param_K =  1
# 0.8577897540892631
# 03/02/2023 13:59
